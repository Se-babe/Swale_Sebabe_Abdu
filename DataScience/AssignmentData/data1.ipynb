# %%
import pandas as pd

# %%
# Load the dataset
sebabe = pd.read_csv('Data.csv')

# %%
sebabe
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#visualize data distribution
import seaborn as sns
import matplotlib.pyplot as plt

sebabe.hist(bins=30, figsize=(20,15))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV file (you already did this)
sebabe= pd.read_csv("data.csv")

# Plot histograms for Maxpulse and Calories
plt.figure(figsize=(10, 4))

# Histogram for Maxpulse
plt.subplot(1, 2, 1)
plt.hist(df['Maxpulse'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Maxpulse')
plt.xlabel('Maxpulse')
plt.ylabel('Frequency')

# Histogram for Calories
plt.subplot(1, 2, 2)
plt.hist(df['Calories'], bins=10, color='lightgreen', edgecolor='black')
plt.title('Histogram of Calories')
plt.xlabel('Calories')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
